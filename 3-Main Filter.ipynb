# %%
import pandas as pd
from scipy.signal import butter, filtfilt
import os
import re
from datetime import datetime

# Define Butterworth filter functions
def butter_lowpass_filter(data, cutoff, fs, order=4):
    nyq = 0.5 * fs
    normal_cutoff = cutoff / nyq
    b, a = butter(order, normal_cutoff, btype='low', analog=False)
    return filtfilt(b, a, data)

# Function to find the date in the file name
def find_date(filename):
    date_pattern = re.compile(r'\d{6,8}')
    match = date_pattern.search(filename)
    return match.group(0) if match else None

# Directories
input_directory = r"D:\Parkinson's\Euclidean_Norm\Resampled Eucledian Distance_2019"
output_directory = r"D:\Parkinson's\Filtered Data"

# Ensure the output directory exists
os.makedirs(output_directory, exist_ok=True)

# Parameters
cutoff_frequency_lp = 20 # Low-pass filter cutoff frequency
order = 4  # Filter order

# Get all files from the input directory
all_files = [f for f in os.listdir(input_directory) if os.path.isfile(os.path.join(input_directory, f))]

for filename in all_files:
    # Construct input and output file paths
    file_path = os.path.join(input_directory, filename)
    
    # Extract the main part of the filename for use in the output filename
    main_part_of_filename = '_'.join(filename.split('_')[:2])  # This assumes the format is always like '3002_03152019_...'
    date_str = find_date(filename)
    if date_str is None:
        print(f"No date found in filename {filename}")
        continue
    
    output_file_path = os.path.join(output_directory, f"{main_part_of_filename}_filtered.csv")
    
    # Load the data
    df = pd.read_csv(file_path)
    
    # Calculate the sampling rate from timestamps
    timestamps = pd.to_datetime(df['Timestamp'], unit='ms')
    sampling_rate = 1 / (timestamps.diff().dt.total_seconds().median())
    
    # Low-pass filter the acceleration data
    df['FilteredEuclideanDistance'] = butter_lowpass_filter(df['EuclideanDistance'], cutoff_frequency_lp, sampling_rate, order)
    
    # Save the filtered data to a new CSV file
    df.to_csv(output_file_path, index=False)

    print(f"Processed and saved filtered data for file {filename} to {output_file_path}")
# Out:
# Processed and saved filtered data for file 12593_03182019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\12593_03182019_filtered.csv
# Processed and saved filtered data for file 13039_10012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\13039_10012019_filtered.csv
# Processed and saved filtered data for file 14281_02192019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\14281_02192019_filtered.csv
# Processed and saved filtered data for file 14331_06052019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\14331_06052019_filtered.csv
# Processed and saved filtered data for file 18567_03202019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\18567_03202019_filtered.csv
# Processed and saved filtered data for file 3002_03152019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3002_03152019_filtered.csv
# Processed and saved filtered data for file 3003_03292019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3003_03292019_filtered.csv
# Processed and saved filtered data for file 3004_03292019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3004_03292019_filtered.csv
# Processed and saved filtered data for file 3013_12112019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3013_12112019_filtered.csv
# Processed and saved filtered data for file 3020_04122019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3020_04122019_filtered.csv
# Processed and saved filtered data for file 3023_06062019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3023_06062019_filtered.csv
# Processed and saved filtered data for file 3028_03122019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3028_03122019_filtered.csv
# Processed and saved filtered data for file 3029_05312019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3029_05312019_filtered.csv
# Processed and saved filtered data for file 3050_03052019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3050_03052019_filtered.csv
# Processed and saved filtered data for file 3055_12182019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3055_12182019_filtered.csv
# Processed and saved filtered data for file 3057_02042019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3057_02042019_filtered.csv
# Processed and saved filtered data for file 3061_04012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3061_04012019_filtered.csv
# Processed and saved filtered data for file 3062_02252019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3062_02252019_filtered.csv
# Processed and saved filtered data for file 3064_05072019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3064_05072019_filtered.csv
# Processed and saved filtered data for file 3066_06192019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3066_06192019_filtered.csv
# Processed and saved filtered data for file 3068_06172019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3068_06172019_filtered.csv
# Processed and saved filtered data for file 3072_11132019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3072_11132019_filtered.csv
# Processed and saved filtered data for file 3074_10282019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3074_10282019_filtered.csv
# Processed and saved filtered data for file 3077_04012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3077_04012019_filtered.csv
# Processed and saved filtered data for file 3078_06102019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3078_06102019_filtered.csv
# Processed and saved filtered data for file 3085_01222019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3085_01222019_filtered.csv
# Processed and saved filtered data for file 3086_03122019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3086_03122019_filtered.csv
# Processed and saved filtered data for file 3119_03282019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3119_03282019_filtered.csv
# Processed and saved filtered data for file 3169_12112019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3169_12112019_filtered.csv
# Processed and saved filtered data for file 3181_10282019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3181_10282019_filtered.csv
# Processed and saved filtered data for file 3207_03132019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3207_03132019_filtered.csv
# Processed and saved filtered data for file 3216_10072019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3216_10072019_filtered.csv
# Processed and saved filtered data for file 3218_10022019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3218_10022019_filtered.csv
# Processed and saved filtered data for file 3223_01092019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3223_01092019_filtered.csv
# Processed and saved filtered data for file 3224_04242019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3224_04242019_filtered.csv
# Processed and saved filtered data for file 3227_05302019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3227_05302019_filtered.csv
# Processed and saved filtered data for file 3234_04252019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3234_04252019_filtered.csv
# Processed and saved filtered data for file 3237_04022019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3237_04022019_filtered.csv
# Processed and saved filtered data for file 3354_05202019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3354_05202019_filtered.csv
# Processed and saved filtered data for file 3366_11112019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3366_11112019_filtered.csv
# Processed and saved filtered data for file 3367_08022019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3367_08022019_filtered.csv
# Processed and saved filtered data for file 3403_07082019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3403_07082019_filtered.csv
# Processed and saved filtered data for file 3404_07012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3404_07012019_filtered.csv
# Processed and saved filtered data for file 3407_10042019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3407_10042019_filtered.csv
# Processed and saved filtered data for file 3415_03222019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3415_03222019_filtered.csv
# Processed and saved filtered data for file 3417_06202019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3417_06202019_filtered.csv
# Processed and saved filtered data for file 3424_07012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3424_07012019_filtered.csv
# Processed and saved filtered data for file 3428_07012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3428_07012019_filtered.csv
# Processed and saved filtered data for file 3429_07012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3429_07012019_filtered.csv
# Processed and saved filtered data for file 3431_09192019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3431_09192019_filtered.csv
# Processed and saved filtered data for file 3433_11012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3433_11012019_filtered.csv
# Processed and saved filtered data for file 3434_10012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3434_10012019_filtered.csv
# Processed and saved filtered data for file 3435_10012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3435_10012019_filtered.csv
# Processed and saved filtered data for file 3439_01312019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3439_01312019_filtered.csv
# Processed and saved filtered data for file 3443_03202019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3443_03202019_filtered.csv
# Processed and saved filtered data for file 3444_04192019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3444_04192019_filtered.csv
# Processed and saved filtered data for file 3446_05312019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3446_05312019_filtered.csv
# Processed and saved filtered data for file 3448_05152019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3448_05152019_filtered.csv
# Processed and saved filtered data for file 3451_12012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3451_12012019_filtered.csv
# Processed and saved filtered data for file 3453_11262019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3453_11262019_filtered.csv
# Processed and saved filtered data for file 3459_05292019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3459_05292019_filtered.csv
# Processed and saved filtered data for file 3460_05292019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3460_05292019_filtered.csv
# Processed and saved filtered data for file 3461_05212019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3461_05212019_filtered.csv
# Processed and saved filtered data for file 3464_10292019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3464_10292019_filtered.csv
# Processed and saved filtered data for file 3465_10222019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3465_10222019_filtered.csv
# Processed and saved filtered data for file 3467_12102019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3467_12102019_filtered.csv
# Processed and saved filtered data for file 3472_06182019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3472_06182019_filtered.csv
# Processed and saved filtered data for file 3503_02052019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3503_02052019_filtered.csv
# Processed and saved filtered data for file 3517_10012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3517_10012019_filtered.csv
# Processed and saved filtered data for file 3521_12012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3521_12012019_filtered.csv
# Processed and saved filtered data for file 3522_12012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3522_12012019_filtered.csv
# Processed and saved filtered data for file 3528_01092019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3528_01092019_filtered.csv
# Processed and saved filtered data for file 3532_03042019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3532_03042019_filtered.csv
# Processed and saved filtered data for file 3540_10012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3540_10012019_filtered.csv
# Processed and saved filtered data for file 3565_07122019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3565_07122019_filtered.csv
# Processed and saved filtered data for file 3567_07102019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3567_07102019_filtered.csv
# Processed and saved filtered data for file 3570_07012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3570_07012019_filtered.csv
# Processed and saved filtered data for file 3572_08262019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3572_08262019_filtered.csv
# Processed and saved filtered data for file 3577_12092019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3577_12092019_filtered.csv
# Processed and saved filtered data for file 3585_07292019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3585_07292019_filtered.csv
# Processed and saved filtered data for file 3586_07082019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3586_07082019_filtered.csv
# Processed and saved filtered data for file 3619_11142019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3619_11142019_filtered.csv
# Processed and saved filtered data for file 3654_04222019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3654_04222019_filtered.csv
# Processed and saved filtered data for file 3666_04022019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3666_04022019_filtered.csv
# Processed and saved filtered data for file 3959_10042019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3959_10042019_filtered.csv
# Processed and saved filtered data for file 3960_12022019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3960_12022019_filtered.csv
# Processed and saved filtered data for file 3966_03082019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3966_03082019_filtered.csv
# Processed and saved filtered data for file 3969_03062019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\3969_03062019_filtered.csv
# Processed and saved filtered data for file 40067_12012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\40067_12012019_filtered.csv
# Processed and saved filtered data for file 4051_05032019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\4051_05032019_filtered.csv
# Processed and saved filtered data for file 4052_07102019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\4052_07102019_filtered.csv
# Processed and saved filtered data for file 4054_06072019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\4054_06072019_filtered.csv
# Processed and saved filtered data for file 4055_07012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\4055_07012019_filtered.csv
# Processed and saved filtered data for file 4056_07012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\4056_07012019_filtered.csv
# Processed and saved filtered data for file 4057_07012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\4057_07012019_filtered.csv
# Processed and saved filtered data for file 4059_08092019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\4059_08092019_filtered.csv
# Processed and saved filtered data for file 4071_08012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\4071_08012019_filtered.csv
# Processed and saved filtered data for file 4073_09162019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\4073_09162019_filtered.csv
# Processed and saved filtered data for file 4074_10022019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\4074_10022019_filtered.csv
# Processed and saved filtered data for file 4091_08012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\4091_08012019_filtered.csv
# Processed and saved filtered data for file 4096_09092019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\4096_09092019_filtered.csv
# Processed and saved filtered data for file 4098_11012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\4098_11012019_filtered.csv
# Processed and saved filtered data for file 4099_12022019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\4099_12022019_filtered.csv
# Processed and saved filtered data for file 4101_11012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\4101_11012019_filtered.csv
# Processed and saved filtered data for file 4102_12012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\4102_12012019_filtered.csv
# Processed and saved filtered data for file 4104_01252019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\4104_01252019_filtered.csv
# Processed and saved filtered data for file 4106_01152019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\4106_01152019_filtered.csv
# Processed and saved filtered data for file 4108_01282019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\4108_01282019_filtered.csv
# Processed and saved filtered data for file 4111_02082019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\4111_02082019_filtered.csv
# Processed and saved filtered data for file 4115_03262019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\4115_03262019_filtered.csv
# Processed and saved filtered data for file 4117_05102019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\4117_05102019_filtered.csv
# Processed and saved filtered data for file 41184_04012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\41184_04012019_filtered.csv
# Processed and saved filtered data for file 41749_07012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\41749_07012019_filtered.csv
# Processed and saved filtered data for file 42724_01222019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\42724_01222019_filtered.csv
# Processed and saved filtered data for file 50009_04022019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\50009_04022019_filtered.csv
# Processed and saved filtered data for file 50192_06012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\50192_06012019_filtered.csv
# Processed and saved filtered data for file 50222_08192019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\50222_08192019_filtered.csv
# Processed and saved filtered data for file 50225_08192019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\50225_08192019_filtered.csv
# Processed and saved filtered data for file 50621_06112019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\50621_06112019_filtered.csv
# Processed and saved filtered data for file 50670_02132019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\50670_02132019_filtered.csv
# Processed and saved filtered data for file 50860_11012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\50860_11012019_filtered.csv
# Processed and saved filtered data for file 50901_12012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\50901_12012019_filtered.csv
# Processed and saved filtered data for file 51186_05162019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\51186_05162019_filtered.csv
# Processed and saved filtered data for file 51252_07012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\51252_07012019_filtered.csv
# Processed and saved filtered data for file 51311_06132019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\51311_06132019_filtered.csv
# Processed and saved filtered data for file 51518_07222019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\51518_07222019_filtered.csv
# Processed and saved filtered data for file 51540_10012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\51540_10012019_filtered.csv
# Processed and saved filtered data for file 51625_08012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\51625_08012019_filtered.csv
# Processed and saved filtered data for file 51731_10092019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\51731_10092019_filtered.csv
# Processed and saved filtered data for file 51867_09012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\51867_09012019_filtered.csv
# Processed and saved filtered data for file 51971_10012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\51971_10012019_filtered.csv
# Processed and saved filtered data for file 52062_01032019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\52062_01032019_filtered.csv
# Processed and saved filtered data for file 52353_11132019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\52353_11132019_filtered.csv
# Processed and saved filtered data for file 52355_02202019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\52355_02202019_filtered.csv
# Processed and saved filtered data for file 52400_10012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\52400_10012019_filtered.csv
# Processed and saved filtered data for file 52752_03012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\52752_03012019_filtered.csv
# Processed and saved filtered data for file 52872_07022019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\52872_07022019_filtered.csv
# Processed and saved filtered data for file 52874_11012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\52874_11012019_filtered.csv
# Processed and saved filtered data for file 52888_06012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\52888_06012019_filtered.csv
# Processed and saved filtered data for file 52982_02012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\52982_02012019_filtered.csv
# Processed and saved filtered data for file 53054_05012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\53054_05012019_filtered.csv
# Processed and saved filtered data for file 53258_05012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\53258_05012019_filtered.csv
# Processed and saved filtered data for file 53308_06012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\53308_06012019_filtered.csv
# Processed and saved filtered data for file 53595_07242019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\53595_07242019_filtered.csv
# Processed and saved filtered data for file 53600_09112019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\53600_09112019_filtered.csv
# Processed and saved filtered data for file 53866_05012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\53866_05012019_filtered.csv
# Processed and saved filtered data for file 53925_06012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\53925_06012019_filtered.csv
# Processed and saved filtered data for file 53988_02012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\53988_02012019_filtered.csv
# Processed and saved filtered data for file 54110_12022019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\54110_12022019_filtered.csv
# Processed and saved filtered data for file 54144_03012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\54144_03012019_filtered.csv
# Processed and saved filtered data for file 54161_10212019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\54161_10212019_filtered.csv
# Processed and saved filtered data for file 54196_08082019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\54196_08082019_filtered.csv
# Processed and saved filtered data for file 54197_06262019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\54197_06262019_filtered.csv
# Processed and saved filtered data for file 54266_05042019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\54266_05042019_filtered.csv
# Processed and saved filtered data for file 54309_08012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\54309_08012019_filtered.csv
# Processed and saved filtered data for file 54391_10072019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\54391_10072019_filtered.csv
# Processed and saved filtered data for file 54991_11012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\54991_11012019_filtered.csv
# Processed and saved filtered data for file 55098_06072019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\55098_06072019_filtered.csv
# Processed and saved filtered data for file 55124_08012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\55124_08012019_filtered.csv
# Processed and saved filtered data for file 55151_07012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\55151_07012019_filtered.csv
# Processed and saved filtered data for file 55251_09012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\55251_09012019_filtered.csv
# Processed and saved filtered data for file 55282_07012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\55282_07012019_filtered.csv
# Processed and saved filtered data for file 55349_07012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\55349_07012019_filtered.csv
# Processed and saved filtered data for file 55380_09012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\55380_09012019_filtered.csv
# Processed and saved filtered data for file 55441_06272019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\55441_06272019_filtered.csv
# Processed and saved filtered data for file 55560_08012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\55560_08012019_filtered.csv
# Processed and saved filtered data for file 55615_06012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\55615_06012019_filtered.csv
# Processed and saved filtered data for file 55822_08082019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\55822_08082019_filtered.csv
# Processed and saved filtered data for file 55842_08232019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\55842_08232019_filtered.csv
# Processed and saved filtered data for file 56048_02012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\56048_02012019_filtered.csv
# Processed and saved filtered data for file 56136_11012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\56136_11012019_filtered.csv
# Processed and saved filtered data for file 56405_05012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\56405_05012019_filtered.csv
# Processed and saved filtered data for file 56435_10032019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\56435_10032019_filtered.csv
# Processed and saved filtered data for file 56492_10042019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\56492_10042019_filtered.csv
# Processed and saved filtered data for file 56582_04122019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\56582_04122019_filtered.csv
# Processed and saved filtered data for file 56744_08012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\56744_08012019_filtered.csv
# Processed and saved filtered data for file 56779_04052019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\56779_04052019_filtered.csv
# Processed and saved filtered data for file 56800_03292019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\56800_03292019_filtered.csv
# Processed and saved filtered data for file 57127_08012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\57127_08012019_filtered.csv
# Processed and saved filtered data for file 57234_09012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\57234_09012019_filtered.csv
# Processed and saved filtered data for file 57277_01032019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\57277_01032019_filtered.csv
# Processed and saved filtered data for file 57398_09062019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\57398_09062019_filtered.csv
# Processed and saved filtered data for file 57605_02212019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\57605_02212019_filtered.csv
# Processed and saved filtered data for file 57887_02132019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\57887_02132019_filtered.csv
# Processed and saved filtered data for file 58026_08212019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\58026_08212019_filtered.csv
# Processed and saved filtered data for file 58030_05012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\58030_05012019_filtered.csv
# Processed and saved filtered data for file 58074_06012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\58074_06012019_filtered.csv
# Processed and saved filtered data for file 58111_11032019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\58111_11032019_filtered.csv
# Processed and saved filtered data for file 58138_03012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\58138_03012019_filtered.csv
# Processed and saved filtered data for file 58164_06012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\58164_06012019_filtered.csv
# Processed and saved filtered data for file 58342_10312019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\58342_10312019_filtered.csv
# Processed and saved filtered data for file 58454_07152019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\58454_07152019_filtered.csv
# Processed and saved filtered data for file 58510_06012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\58510_06012019_filtered.csv
# Processed and saved filtered data for file 58550_09012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\58550_09012019_filtered.csv
# Processed and saved filtered data for file 58671_08012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\58671_08012019_filtered.csv
# Processed and saved filtered data for file 58680_08012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\58680_08012019_filtered.csv
# Processed and saved filtered data for file 58721_07182019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\58721_07182019_filtered.csv
# Processed and saved filtered data for file 58783_08012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\58783_08012019_filtered.csv
# Processed and saved filtered data for file 58843_05012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\58843_05012019_filtered.csv
# Processed and saved filtered data for file 58916_10012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\58916_10012019_filtered.csv
# Processed and saved filtered data for file 58990_06012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\58990_06012019_filtered.csv
# Processed and saved filtered data for file 59042_10032019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\59042_10032019_filtered.csv
# Processed and saved filtered data for file 59121_10012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\59121_10012019_filtered.csv
# Processed and saved filtered data for file 59174_06012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\59174_06012019_filtered.csv
# Processed and saved filtered data for file 59178_07022019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\59178_07022019_filtered.csv
# Processed and saved filtered data for file 59310_11012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\59310_11012019_filtered.csv
# Processed and saved filtered data for file 59409_08282019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\59409_08282019_filtered.csv
# Processed and saved filtered data for file 59466_09182019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\59466_09182019_filtered.csv
# Processed and saved filtered data for file 59558_07012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\59558_07012019_filtered.csv
# Processed and saved filtered data for file 59724_08012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\59724_08012019_filtered.csv
# Processed and saved filtered data for file 59797_01012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\59797_01012019_filtered.csv
# Processed and saved filtered data for file 59797_12012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\59797_12012019_filtered.csv
# Processed and saved filtered data for file 59866_07112019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\59866_07112019_filtered.csv
# Processed and saved filtered data for file 60013_10012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\60013_10012019_filtered.csv
# Processed and saved filtered data for file 65002_11012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\65002_11012019_filtered.csv
# Processed and saved filtered data for file 70035_07012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\70035_07012019_filtered.csv
# Processed and saved filtered data for file 70106_08012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\70106_08012019_filtered.csv
# Processed and saved filtered data for file 70179_01102019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\70179_01102019_filtered.csv
# Processed and saved filtered data for file 70188_10012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\70188_10012019_filtered.csv
# Processed and saved filtered data for file 70326_08012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\70326_08012019_filtered.csv
# Processed and saved filtered data for file 70345_10012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\70345_10012019_filtered.csv
# Processed and saved filtered data for file 70378_12012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\70378_12012019_filtered.csv
# Processed and saved filtered data for file 70432_09092019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\70432_09092019_filtered.csv
# Processed and saved filtered data for file 70519_11222019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\70519_11222019_filtered.csv
# Processed and saved filtered data for file 70631_11012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\70631_11012019_filtered.csv
# Processed and saved filtered data for file 70645_09012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\70645_09012019_filtered.csv
# Processed and saved filtered data for file 70652_10012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\70652_10012019_filtered.csv
# Processed and saved filtered data for file 70659_11012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\70659_11012019_filtered.csv
# Processed and saved filtered data for file 70810_03272019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\70810_03272019_filtered.csv
# Processed and saved filtered data for file 71065_01012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\71065_01012019_filtered.csv
# Processed and saved filtered data for file 71189_10102019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\71189_10102019_filtered.csv
# Processed and saved filtered data for file 71215_05312019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\71215_05312019_filtered.csv
# Processed and saved filtered data for file 71394_03012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\71394_03012019_filtered.csv
# Processed and saved filtered data for file 71658_11012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\71658_11012019_filtered.csv
# Processed and saved filtered data for file 71770_12012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\71770_12012019_filtered.csv
# Processed and saved filtered data for file 71809_11012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\71809_11012019_filtered.csv
# Processed and saved filtered data for file 72110_09012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\72110_09012019_filtered.csv
# Processed and saved filtered data for file 72138_12012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\72138_12012019_filtered.csv
# Processed and saved filtered data for file 72222_04012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\72222_04012019_filtered.csv
# Processed and saved filtered data for file 72352_01012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\72352_01012019_filtered.csv
# Processed and saved filtered data for file 72419_10012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\72419_10012019_filtered.csv
# Processed and saved filtered data for file 72562_09302019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\72562_09302019_filtered.csv
# Processed and saved filtered data for file 72651_09122019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\72651_09122019_filtered.csv
# Processed and saved filtered data for file 72784_12122019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\72784_12122019_filtered.csv
# Processed and saved filtered data for file 72877_11222019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\72877_11222019_filtered.csv
# Processed and saved filtered data for file 73082_06012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\73082_06012019_filtered.csv
# Processed and saved filtered data for file 73134_01012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\73134_01012019_filtered.csv
# Processed and saved filtered data for file 73134_12012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\73134_12012019_filtered.csv
# Processed and saved filtered data for file 73397_10182019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\73397_10182019_filtered.csv
# Processed and saved filtered data for file 73432_10012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\73432_10012019_filtered.csv
# Processed and saved filtered data for file 73614_02012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\73614_02012019_filtered.csv
# Processed and saved filtered data for file 73787_12012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\73787_12012019_filtered.csv
# Processed and saved filtered data for file 73887_07012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\73887_07012019_filtered.csv
# Processed and saved filtered data for file 73935_11012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\73935_11012019_filtered.csv
# Processed and saved filtered data for file 74034_04012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\74034_04012019_filtered.csv
# Processed and saved filtered data for file 74067_05012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\74067_05012019_filtered.csv
# Processed and saved filtered data for file 74251_12022019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\74251_12022019_filtered.csv
# Processed and saved filtered data for file 74497_10012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\74497_10012019_filtered.csv
# Processed and saved filtered data for file 74696_11012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\74696_11012019_filtered.csv
# Processed and saved filtered data for file 75403_05312019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\75403_05312019_filtered.csv
# Processed and saved filtered data for file 75411_11202019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\75411_11202019_filtered.csv
# Processed and saved filtered data for file 75420_09012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\75420_09012019_filtered.csv
# Processed and saved filtered data for file 75421_10162019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\75421_10162019_filtered.csv
# Processed and saved filtered data for file 75423_11012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\75423_11012019_filtered.csv
# Processed and saved filtered data for file 75434_11012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\75434_11012019_filtered.csv
# Processed and saved filtered data for file 75484_12022019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\75484_12022019_filtered.csv
# Processed and saved filtered data for file 75492_10012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\75492_10012019_filtered.csv
# Processed and saved filtered data for file 75496_10012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\75496_10012019_filtered.csv
# Processed and saved filtered data for file 75508_11012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\75508_11012019_filtered.csv
# Processed and saved filtered data for file 75512_12012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\75512_12012019_filtered.csv
# Processed and saved filtered data for file 75547_12012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\75547_12012019_filtered.csv
# Processed and saved filtered data for file 90456_09012019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\90456_09012019_filtered.csv
# Processed and saved filtered data for file 91097_07112019_Euclidean_Norms_output.csv to D:\Parkinson's\Filtered Data\91097_07112019_filtered.csv
