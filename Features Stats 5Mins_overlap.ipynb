# %%
import os
import pandas as pd

def process_files(input_directory, output_directory):
    # Ensure the output directory exists
    if not os.path.exists(output_directory):
        os.makedirs(output_directory)

    # Iterate over all files in the input directory
    for filename in os.listdir(input_directory):
        if filename.endswith(".csv"):
            # Construct the full file path
            file_path = os.path.join(input_directory, filename)
            
            # Load the CSV file
            data = pd.read_csv(file_path)
            
            # Calculate descriptive statistics and drop 'count'
            descriptive_stats = data.describe().drop('count')
            
            # Flatten the DataFrame to a single row per feature set
            descriptive_stats_flat = descriptive_stats.unstack().to_frame().T
            
            # Create new column names by combining the statistic with the feature name
            descriptive_stats_flat.columns = ['{}_{}'.format(stat, feature) for feature, stat in descriptive_stats_flat.columns]
            
            # Construct the output file path
            base_filename = os.path.splitext(filename)[0]
            output_filename = f"{base_filename}_stats.csv"
            output_filepath = os.path.join(output_directory, output_filename)
            
            # Save the flattened descriptive statistics to CSV
            descriptive_stats_flat.to_csv(output_filepath, index=False)
            
            print(f"Processed and saved: {output_filename}")

# Define the input and output directories
input_directory = 'D:\\Parkinson\'s\\Feature extraction\\Features_Extraction_5mins_overlap'
output_directory = 'D:\\Parkinson\'s\\Feature extraction\\Features_Extraction_5mins_overlap\\Stats'

# Process all files
process_files(input_directory, output_directory)
# Out:
# Processed and saved: 12593_03182019_TSFEL_features_stats.csv
# Processed and saved: 13039_10012019_TSFEL_features_stats.csv
# Processed and saved: 14281_02192019_TSFEL_features_stats.csv
# Processed and saved: 14331_06052019_TSFEL_features_stats.csv
# Processed and saved: 18567_03202019_TSFEL_features_stats.csv
# Processed and saved: 3002_03152019_TSFEL_features_stats.csv
# Processed and saved: 3003_03292019_TSFEL_features_stats.csv
# Processed and saved: 3004_03292019_TSFEL_features_stats.csv
# Processed and saved: 3013_12112019_TSFEL_features_stats.csv
# Processed and saved: 3020_04122019_TSFEL_features_stats.csv
# Processed and saved: 3023_06062019_TSFEL_features_stats.csv
# Processed and saved: 3028_03122019_TSFEL_features_stats.csv
# Processed and saved: 3029_05312019_TSFEL_features_stats.csv
# Processed and saved: 3050_03052019_TSFEL_features_stats.csv
# Processed and saved: 3055_12182019_TSFEL_features_stats.csv
# Processed and saved: 3057_02042019_TSFEL_features_stats.csv
# Processed and saved: 3061_04012019_TSFEL_features_stats.csv
# Processed and saved: 3062_02252019_TSFEL_features_stats.csv
# Processed and saved: 3064_05072019_TSFEL_features_stats.csv
# Processed and saved: 3066_06192019_TSFEL_features_stats.csv
# Processed and saved: 3068_06172019_TSFEL_features_stats.csv
# Processed and saved: 3072_11132019_TSFEL_features_stats.csv
# Processed and saved: 3074_10282019_TSFEL_features_stats.csv
# Processed and saved: 3077_04012019_TSFEL_features_stats.csv
# Processed and saved: 3078_06102019_TSFEL_features_stats.csv
# Processed and saved: 3085_01222019_TSFEL_features_stats.csv
# Processed and saved: 3086_03122019_TSFEL_features_stats.csv
# Processed and saved: 3169_12112019_TSFEL_features_stats.csv
# Processed and saved: 3181_10282019_TSFEL_features_stats.csv
# Processed and saved: 3207_03132019_TSFEL_features_stats.csv
# Processed and saved: 3216_10072019_TSFEL_features_stats.csv
# Processed and saved: 3218_10022019_TSFEL_features_stats.csv
# Processed and saved: 3223_01092019_TSFEL_features_stats.csv
# Processed and saved: 3224_04242019_TSFEL_features_stats.csv
# Processed and saved: 3227_05302019_TSFEL_features_stats.csv
# Processed and saved: 3234_04252019_TSFEL_features_stats.csv
# Processed and saved: 3237_04022019_TSFEL_features_stats.csv
# Processed and saved: 3354_05202019_TSFEL_features_stats.csv
# Processed and saved: 3366_11112019_TSFEL_features_stats.csv
# Processed and saved: 3367_08022019_TSFEL_features_stats.csv
# Processed and saved: 3403_07082019_TSFEL_features_stats.csv
# Processed and saved: 3404_07012019_TSFEL_features_stats.csv
# Processed and saved: 3407_10042019_TSFEL_features_stats.csv
# Processed and saved: 3415_03222019_TSFEL_features_stats.csv
# Processed and saved: 3417_06202019_TSFEL_features_stats.csv
# Processed and saved: 3424_07012019_TSFEL_features_stats.csv
# Processed and saved: 3428_07012019_TSFEL_features_stats.csv
# Processed and saved: 3429_07012019_TSFEL_features_stats.csv
# Processed and saved: 3431_09192019_TSFEL_features_stats.csv
# Processed and saved: 3433_11012019_TSFEL_features_stats.csv
# Processed and saved: 3434_10012019_TSFEL_features_stats.csv
# Processed and saved: 3435_10012019_TSFEL_features_stats.csv
# Processed and saved: 3439_01312019_TSFEL_features_stats.csv
# Processed and saved: 3443_03202019_TSFEL_features_stats.csv
# Processed and saved: 3444_04192019_TSFEL_features_stats.csv
# Processed and saved: 3446_05312019_TSFEL_features_stats.csv
# Processed and saved: 3448_05152019_TSFEL_features_stats.csv
# Processed and saved: 3451_12012019_TSFEL_features_stats.csv
# Processed and saved: 3453_11262019_TSFEL_features_stats.csv
# Processed and saved: 3459_05292019_TSFEL_features_stats.csv
# Processed and saved: 3460_05292019_TSFEL_features_stats.csv
# Processed and saved: 3461_05212019_TSFEL_features_stats.csv
# Processed and saved: 3464_10292019_TSFEL_features_stats.csv
# Processed and saved: 3465_10222019_TSFEL_features_stats.csv
# Processed and saved: 3467_12102019_TSFEL_features_stats.csv
# Processed and saved: 3472_06182019_TSFEL_features_stats.csv
# Processed and saved: 3503_02052019_TSFEL_features_stats.csv
# Processed and saved: 3517_10012019_TSFEL_features_stats.csv
# Processed and saved: 3521_12012019_TSFEL_features_stats.csv
# Processed and saved: 3522_12012019_TSFEL_features_stats.csv
# Processed and saved: 3528_01092019_TSFEL_features_stats.csv
# Processed and saved: 3532_03042019_TSFEL_features_stats.csv
# Processed and saved: 3540_10012019_TSFEL_features_stats.csv
# Processed and saved: 3565_07122019_TSFEL_features_stats.csv
# Processed and saved: 3567_07102019_TSFEL_features_stats.csv
# Processed and saved: 3570_07012019_TSFEL_features_stats.csv
# Processed and saved: 3572_08262019_TSFEL_features_stats.csv
# Processed and saved: 3577_12092019_TSFEL_features_stats.csv
# Processed and saved: 3585_07292019_TSFEL_features_stats.csv
# Processed and saved: 3586_07082019_TSFEL_features_stats.csv
# Processed and saved: 3619_11142019_TSFEL_features_stats.csv
# Processed and saved: 3654_04222019_TSFEL_features_stats.csv
# Processed and saved: 3666_04022019_TSFEL_features_stats.csv
# Processed and saved: 3959_10042019_TSFEL_features_stats.csv
# Processed and saved: 3960_12022019_TSFEL_features_stats.csv
# Processed and saved: 3966_03082019_TSFEL_features_stats.csv
# Processed and saved: 3969_03062019_TSFEL_features_stats.csv
# Processed and saved: 40067_12012019_TSFEL_features_stats.csv
# Processed and saved: 4051_05032019_TSFEL_features_stats.csv
# Processed and saved: 4052_07102019_TSFEL_features_stats.csv
# Processed and saved: 4054_06072019_TSFEL_features_stats.csv
# Processed and saved: 4055_07012019_TSFEL_features_stats.csv
# Processed and saved: 4056_07012019_TSFEL_features_stats.csv
# Processed and saved: 4057_07012019_TSFEL_features_stats.csv
# Processed and saved: 4071_08012019_TSFEL_features_stats.csv
# Processed and saved: 4073_09162019_TSFEL_features_stats.csv
# Processed and saved: 4074_10022019_TSFEL_features_stats.csv
# Processed and saved: 4091_08012019_TSFEL_features_stats.csv
# Processed and saved: 4096_09092019_TSFEL_features_stats.csv
# Processed and saved: 4098_11012019_TSFEL_features_stats.csv
# Processed and saved: 4099_12022019_TSFEL_features_stats.csv
# Processed and saved: 4101_11012019_TSFEL_features_stats.csv
# Processed and saved: 4102_12012019_TSFEL_features_stats.csv
# Processed and saved: 4104_01252019_TSFEL_features_stats.csv
# Processed and saved: 4106_01152019_TSFEL_features_stats.csv
# Processed and saved: 4108_01282019_TSFEL_features_stats.csv
# Processed and saved: 4111_02082019_TSFEL_features_stats.csv
# Processed and saved: 4115_03262019_TSFEL_features_stats.csv
# Processed and saved: 4117_05102019_TSFEL_features_stats.csv
# Processed and saved: 41184_04012019_TSFEL_features_stats.csv
# Processed and saved: 41749_07012019_TSFEL_features_stats.csv
# Processed and saved: 42724_01222019_TSFEL_features_stats.csv
# Processed and saved: 50009_04022019_TSFEL_features_stats.csv
# Processed and saved: 50192_06012019_TSFEL_features_stats.csv
# Processed and saved: 50222_08192019_TSFEL_features_stats.csv
# Processed and saved: 50225_08192019_TSFEL_features_stats.csv
# Processed and saved: 50621_06112019_TSFEL_features_stats.csv
# Processed and saved: 50670_02132019_TSFEL_features_stats.csv
# Processed and saved: 50860_11012019_TSFEL_features_stats.csv
# Processed and saved: 50901_12012019_TSFEL_features_stats.csv
# Processed and saved: 51186_05162019_TSFEL_features_stats.csv
# Processed and saved: 51252_07012019_TSFEL_features_stats.csv
# Processed and saved: 51311_06132019_TSFEL_features_stats.csv
# Processed and saved: 51518_07222019_TSFEL_features_stats.csv
# Processed and saved: 51540_10012019_TSFEL_features_stats.csv
# Processed and saved: 51625_08012019_TSFEL_features_stats.csv
# Processed and saved: 51731_10092019_TSFEL_features_stats.csv
# Processed and saved: 51867_09012019_TSFEL_features_stats.csv
# Processed and saved: 51971_10012019_TSFEL_features_stats.csv
# Processed and saved: 52062_01032019_TSFEL_features_stats.csv
# Processed and saved: 52353_11132019_TSFEL_features_stats.csv
# Processed and saved: 52355_02202019_TSFEL_features_stats.csv
# Processed and saved: 52400_10012019_TSFEL_features_stats.csv
# Processed and saved: 52752_03012019_TSFEL_features_stats.csv
# Processed and saved: 52872_07022019_TSFEL_features_stats.csv
# Processed and saved: 52874_11012019_TSFEL_features_stats.csv
# Processed and saved: 52888_06012019_TSFEL_features_stats.csv
# Processed and saved: 52982_02012019_TSFEL_features_stats.csv
# Processed and saved: 53054_05012019_TSFEL_features_stats.csv
# Processed and saved: 53308_06012019_TSFEL_features_stats.csv
# Processed and saved: 53595_07242019_TSFEL_features_stats.csv
# Processed and saved: 53600_09112019_TSFEL_features_stats.csv
# Processed and saved: 53866_05012019_TSFEL_features_stats.csv
# Processed and saved: 53988_02012019_TSFEL_features_stats.csv
# Processed and saved: 54110_12022019_TSFEL_features_stats.csv
# Processed and saved: 54144_03012019_TSFEL_features_stats.csv
# Processed and saved: 54161_10212019_TSFEL_features_stats.csv
# Processed and saved: 54196_08082019_TSFEL_features_stats.csv
# Processed and saved: 54197_06262019_TSFEL_features_stats.csv
# Processed and saved: 54266_05042019_TSFEL_features_stats.csv
# Processed and saved: 54309_08012019_TSFEL_features_stats.csv
# Processed and saved: 54391_10072019_TSFEL_features_stats.csv
# Processed and saved: 54991_11012019_TSFEL_features_stats.csv
# Processed and saved: 55098_06072019_TSFEL_features_stats.csv
# Processed and saved: 55124_08012019_TSFEL_features_stats.csv
# Processed and saved: 55151_07012019_TSFEL_features_stats.csv
# Processed and saved: 55251_09012019_TSFEL_features_stats.csv
# Processed and saved: 55282_07012019_TSFEL_features_stats.csv
# Processed and saved: 55349_07012019_TSFEL_features_stats.csv
# Processed and saved: 55441_06272019_TSFEL_features_stats.csv
# Processed and saved: 55560_08012019_TSFEL_features_stats.csv
# Processed and saved: 55615_06012019_TSFEL_features_stats.csv
# Processed and saved: 55822_08082019_TSFEL_features_stats.csv
# Processed and saved: 55842_08232019_TSFEL_features_stats.csv
# Processed and saved: 56048_02012019_TSFEL_features_stats.csv
# Processed and saved: 56136_11012019_TSFEL_features_stats.csv
# Processed and saved: 56405_05012019_TSFEL_features_stats.csv
# Processed and saved: 56435_10032019_TSFEL_features_stats.csv
# Processed and saved: 56492_10042019_TSFEL_features_stats.csv
# Processed and saved: 56582_04122019_TSFEL_features_stats.csv
# Processed and saved: 56744_08012019_TSFEL_features_stats.csv
# Processed and saved: 56779_04052019_TSFEL_features_stats.csv
# Processed and saved: 56800_03292019_TSFEL_features_stats.csv
# Processed and saved: 57127_08012019_TSFEL_features_stats.csv
# Processed and saved: 57234_09012019_TSFEL_features_stats.csv
# Processed and saved: 57277_01032019_TSFEL_features_stats.csv
# Processed and saved: 57398_09062019_TSFEL_features_stats.csv
# Processed and saved: 57887_02132019_TSFEL_features_stats.csv
# Processed and saved: 58026_08212019_TSFEL_features_stats.csv
# Processed and saved: 58030_05012019_TSFEL_features_stats.csv
# Processed and saved: 58074_06012019_TSFEL_features_stats.csv
# Processed and saved: 58138_03012019_TSFEL_features_stats.csv
# Processed and saved: 58164_06012019_TSFEL_features_stats.csv
# Processed and saved: 58342_10312019_TSFEL_features_stats.csv
# Processed and saved: 58454_07152019_TSFEL_features_stats.csv
# Processed and saved: 58510_06012019_TSFEL_features_stats.csv
# Processed and saved: 58550_09012019_TSFEL_features_stats.csv
# Processed and saved: 58671_08012019_TSFEL_features_stats.csv
# Processed and saved: 58680_08012019_TSFEL_features_stats.csv
# Processed and saved: 58721_07182019_TSFEL_features_stats.csv
# Processed and saved: 58783_08012019_TSFEL_features_stats.csv
# Processed and saved: 58843_05012019_TSFEL_features_stats.csv
# Processed and saved: 58916_10012019_TSFEL_features_stats.csv
# Processed and saved: 59042_10032019_TSFEL_features_stats.csv
# Processed and saved: 59121_10012019_TSFEL_features_stats.csv
# Processed and saved: 59174_06012019_TSFEL_features_stats.csv
# Processed and saved: 59178_07022019_TSFEL_features_stats.csv
# Processed and saved: 59310_11012019_TSFEL_features_stats.csv
# Processed and saved: 59409_08282019_TSFEL_features_stats.csv
# Processed and saved: 59558_07012019_TSFEL_features_stats.csv
# Processed and saved: 59724_08012019_TSFEL_features_stats.csv
# Processed and saved: 59797_12012019_TSFEL_features_stats.csv
# Processed and saved: 60013_10012019_TSFEL_features_stats.csv
# Processed and saved: 65002_11012019_TSFEL_features_stats.csv
# Processed and saved: 70035_07012019_TSFEL_features_stats.csv
# Processed and saved: 70106_08012019_TSFEL_features_stats.csv
# Processed and saved: 70179_01102019_TSFEL_features_stats.csv
# Processed and saved: 70188_10012019_TSFEL_features_stats.csv
# Processed and saved: 70326_08012019_TSFEL_features_stats.csv
# Processed and saved: 70345_10012019_TSFEL_features_stats.csv
# Processed and saved: 70378_12012019_TSFEL_features_stats.csv
# Processed and saved: 70432_09092019_TSFEL_features_stats.csv
# Processed and saved: 70519_11222019_TSFEL_features_stats.csv
# Processed and saved: 70631_11012019_TSFEL_features_stats.csv
# Processed and saved: 70645_09012019_TSFEL_features_stats.csv
# Processed and saved: 70652_10012019_TSFEL_features_stats.csv
# Processed and saved: 70659_11012019_TSFEL_features_stats.csv
# Processed and saved: 70810_03272019_TSFEL_features_stats.csv
# Processed and saved: 71065_01012019_TSFEL_features_stats.csv
# Processed and saved: 71189_10102019_TSFEL_features_stats.csv
# Processed and saved: 71215_05312019_TSFEL_features_stats.csv
# Processed and saved: 71394_03012019_TSFEL_features_stats.csv
# Processed and saved: 71658_11012019_TSFEL_features_stats.csv
# Processed and saved: 71770_12012019_TSFEL_features_stats.csv
# Processed and saved: 71809_11012019_TSFEL_features_stats.csv
# Processed and saved: 72110_09012019_TSFEL_features_stats.csv
# Processed and saved: 72138_12012019_TSFEL_features_stats.csv
# Processed and saved: 72222_04012019_TSFEL_features_stats.csv
# Processed and saved: 72352_01012019_TSFEL_features_stats.csv
# Processed and saved: 72419_10012019_TSFEL_features_stats.csv
# Processed and saved: 72651_09122019_TSFEL_features_stats.csv
# Processed and saved: 72784_12122019_TSFEL_features_stats.csv
# Processed and saved: 72877_11222019_TSFEL_features_stats.csv
# Processed and saved: 73082_06012019_TSFEL_features_stats.csv
# Processed and saved: 73134_01012019_TSFEL_features_stats.csv
# Processed and saved: 73134_12012019_TSFEL_features_stats.csv
# Processed and saved: 73397_10182019_TSFEL_features_stats.csv
# Processed and saved: 73432_10012019_TSFEL_features_stats.csv
# Processed and saved: 73614_02012019_TSFEL_features_stats.csv
# Processed and saved: 73787_12012019_TSFEL_features_stats.csv
# Processed and saved: 73887_07012019_TSFEL_features_stats.csv
# Processed and saved: 73935_11012019_TSFEL_features_stats.csv
# Processed and saved: 74034_04012019_TSFEL_features_stats.csv
# Processed and saved: 74067_05012019_TSFEL_features_stats.csv
# Processed and saved: 74251_12022019_TSFEL_features_stats.csv
# Processed and saved: 74497_10012019_TSFEL_features_stats.csv
# Processed and saved: 74696_11012019_TSFEL_features_stats.csv
# Processed and saved: 75403_05312019_TSFEL_features_stats.csv
# Processed and saved: 75411_11202019_TSFEL_features_stats.csv
# Processed and saved: 75420_09012019_TSFEL_features_stats.csv
# Processed and saved: 75421_10162019_TSFEL_features_stats.csv
# Processed and saved: 75423_11012019_TSFEL_features_stats.csv
# Processed and saved: 75434_11012019_TSFEL_features_stats.csv
# Processed and saved: 75484_12022019_TSFEL_features_stats.csv
# Processed and saved: 75492_10012019_TSFEL_features_stats.csv
# Processed and saved: 75496_10012019_TSFEL_features_stats.csv
# Processed and saved: 75508_11012019_TSFEL_features_stats.csv
# Processed and saved: 75512_12012019_TSFEL_features_stats.csv
# Processed and saved: 75547_12012019_TSFEL_features_stats.csv
# Processed and saved: 90456_09012019_TSFEL_features_stats.csv
# Processed and saved: 91097_07112019_TSFEL_features_stats.csv

# %%
import os
import pandas as pd

def combine_files_with_patient_number(input_directory, output_filename):
    combined_df = pd.DataFrame()  # Initialize an empty DataFrame to hold combined data
    
    # Iterate over all files in the input directory
    for filename in os.listdir(input_directory):
        if filename.endswith(".csv"):  # Ensure we're only processing CSV files
            file_path = os.path.join(input_directory, filename)
            # Extract the patient number from the filename
            patient_number = filename.split('_')[0]
            # Read the current file into a DataFrame
            temp_df = pd.read_csv(file_path)
            # Add the patient number as a new column
            temp_df['PatientNumber'] = patient_number
            # Append the data from the current file to the combined DataFrame
            combined_df = pd.concat([combined_df, temp_df], axis=0, ignore_index=True)
    
    # Save the combined DataFrame to an Excel file
    combined_df.to_excel(output_filename, index=False)
    print(f"Combined file with patient numbers saved as: {output_filename}")

# Define the input directory and output filename
input_directory = 'D:\\Parkinson\'s\\Feature extraction\\Features_Extraction_5mins_overlap\\Stats'
output_filename = 'D:\\Parkinson\'s\\Feature extraction\\Features_Extraction_5mins_overlap\\TSFEL_features_5mins_overlap_combine.xlsx'


# Combine all files and include patient numbers
combine_files_with_patient_number(input_directory, output_filename)
# Out:
# Combined file with patient numbers saved as: D:\Parkinson's\Feature extraction\Features_Extraction_5mins_overlap\TSFEL_features_5mins_overlap_combine.xlsx

# %%
import pandas as pd

# Load the combined TSFEL features Excel file
combined_path = 'D:\\Parkinson\'s\\Feature extraction\\Features_Extraction_5mins_overlap\\TSFEL_features_5mins_overlap_combine.xlsx'
combined_df = pd.read_excel(combined_path)

# Load the additional data Excel file and the specific sheet
additional_data_path = 'D:\\Data Count (2).xlsx'
additional_df = pd.read_excel(additional_data_path, sheet_name='2019 Data Match')

# We're interested in the following columns from the additional data
additional_columns = ['PATNO', 'MOCA(2019)', 'Age', 'Sex', 'EDUCATION YEARS', 'Parkinson\'s Vs Control']

# Filter the additional data DataFrame to only include these columns
additional_df_filtered = additional_df[additional_columns]

# Convert PATNO to string if it's not already, to ensure matching works correctly
additional_df_filtered['PATNO'] = additional_df_filtered['PATNO'].astype(str)
combined_df['PatientNumber'] = combined_df['PatientNumber'].astype(str)

# Merge the combined DataFrame with the additional information
# This assumes 'PatientNumber' in the combined_df matches 'PATNO' in the additional_df_filtered
combined_updated_df = pd.merge(combined_df, additional_df_filtered, left_on='PatientNumber', right_on='PATNO', how='left')

# Drop the PATNO column after the merge, as it's redundant
combined_updated_df.drop('PATNO', axis=1, inplace=True)

# Save the updated combined DataFrame back to Excel
combined_updated_df.to_excel(combined_path, index=False)

print(f"Combined file has been updated and saved back to: {combined_path}")
# Out:
# C:\Users\upama\AppData\Local\Temp\ipykernel_24228\3133490420.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   additional_df_filtered['PATNO'] = additional_df_filtered['PATNO'].astype(str)
# Combined file has been updated and saved back to: D:\Parkinson's\Feature extraction\Features_Extraction_5mins_overlap\TSFEL_features_5mins_overlap_combine.xlsx
